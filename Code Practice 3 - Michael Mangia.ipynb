# %% [markdown]
# Michael Mangia
#
# Code Practice 3

# %% [markdown]
# **1.)**

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %% [markdown]
# a.) Import allows you to take in a library for python and use it as a tool in your code

# %% [markdown]
# b.) The variable data is a dictionary

# %% [markdown]
# c.) "pd" calls the pandas library that we have uploaded into the notebook

# %% [markdown]
# d.) Weo is a pandas dataframe.

# %% [markdown]
# e.) There are 7 rows and 4 columns

# %% [markdown]
# f.)

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %%
weo.shape
# Out:
# (7, 4)

# %% [markdown]
# g.)

# %%
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %% [markdown]
# This is a series in pandas

# %%
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %% [markdown]
# This is a data frame

# %%
## weo[[3]]
##This kicks back an error. However if we use the following expression


weo.loc[3]

##we get the third index 2011 for the three countries.
##this is a series
# Out:
# BRA       15.07
# JPN       34.29
# USA       49.72
# Year    2011.00
# Name: 3, dtype: float64

# %%
#g
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %% [markdown]
# h.)

# %%
weo["Year"] = weo["Year"].astype(float)

# %% [markdown]
# i.)

# %%
weo.tail(3)
# Out:
#      BRA    JPN    USA    Year
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %% [markdown]
# This is a data frame. It is the last 3 rows of weo.

# %% [markdown]
# j.)

# %%
new_weo = weo.head(4)

# %%
new_weo
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0

# %% [markdown]
# k.)

# %% [markdown]
# type(weo["BRA"])

# %% [markdown]
# This is a series in one column

# %% [markdown]
# l.)

# %%
weo ["rat"] = weo ["BRA"] /weo["JPN"]

# %%
weo
# Out:
#      BRA    JPN    USA    Year       rat
# 0  13.37  33.43  48.30  2008.0  0.399940
# 1  13.30  31.83  46.91  2009.0  0.417845
# 2  14.34  33.71  48.31  2010.0  0.425393
# 3  15.07  34.29  49.72  2011.0  0.439487
# 4  15.46  35.60  51.41  2012.0  0.434270
# 5  15.98  36.79  52.94  2013.0  0.434357
# 6  16.10  37.39  54.60  2014.0  0.430596

# %% [markdown]
# m.)

# %%
weo.drop("rat", axis = 1 , inplace = True)

# %% [markdown]
# n.)

# %%
print(weo.columns)
# Out:
# Index(['BRA', 'JPN', 'USA', 'Year'], dtype='object')

# %%
print(weo.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# o.)

# %%
weo.set_index("Year", inplace = True)

# %% [markdown]
# P.)

# %%
weo = weo.rename(columns = { 'USA': "United States","BRA":"Brazil", "JPN":"Japan"})

# %%
weo
# Out:
#         Brazil  Japan  United States
# Year
# 2008.0   13.37  33.43          48.30
# 2009.0   13.30  31.83          46.91
# 2010.0   14.34  33.71          48.31
# 2011.0   15.07  34.29          49.72
# 2012.0   15.46  35.60          51.41
# 2013.0   15.98  36.79          52.94
# 2014.0   16.10  37.39          54.60

# %% [markdown]
# Q.)

# %%
weo.to_excel("output.xlsx")

# %% [markdown]
# R.)

# %%
print(weo.mean)
# Out:
# <bound method DataFrame.mean of         Brazil  Japan  United States
# Year
# 2008.0   13.37  33.43          48.30
# 2009.0   13.30  31.83          46.91
# 2010.0   14.34  33.71          48.31
# 2011.0   15.07  34.29          49.72
# 2012.0   15.46  35.60          51.41
# 2013.0   15.98  36.79          52.94
# 2014.0   16.10  37.39          54.60>

# %% [markdown]
# S.)

# %%
weo.mean(axis=1)
# Out:
# Year
# 2008.0    31.700000
# 2009.0    30.680000
# 2010.0    32.120000
# 2011.0    33.026667
# 2012.0    34.156667
# 2013.0    35.236667
# 2014.0    36.030000
# dtype: float64

# %% [markdown]
# T.)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
graph = weo.plot()

# %% [markdown]
# U.)

# %%
graph = weo.plot(color=["green","red","blue"])

# %% [markdown]
# V.)

# %%
graph = weo.plot(color=["green","red","blue"] , logx = True)

# %%
graph = weo.plot(color=["green","red","blue"] , logy = True)

# %% [markdown]
# W.)

# %%
weo["Brazil"].plot()

# %% [markdown]
# **2.)**

# %% [markdown]
# a.)

# %%
ep = pd.read_csv("entry_poll_fall16.csv")

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# B.)

# %% [markdown]
# This file contains questions and answers to a series of questions to NYU stern students.

# %% [markdown]
# C.)

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# D.)

# %%
ep.columns = ["Time", "Enrollment", "Program", "Compp_Exp", "Prob_Exp", "Major", "Career", "SM", "Data", "Topics"]

# %% [markdown]
# E.)

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# To finish my major                                    1
# Recommended by a professor.                           1
# I like a challenge                                    1
# I code/build websites in my spare time as a hobby     1
# Wanted to try something completely different          1
# i am living in Santiago de Chile                      1
# Name: Enrollment, dtype: int64

# %% [markdown]
# ep.head()

# %% [markdown]
# This program takes all of the responses in the first column and sums the amount of times that each response occurs

# %%
list(ep)[1]
# Out:
# 'Enrollment'

# %% [markdown]
# This first creates a list of the column name that is extracted

# %%
ep[list(ep)[1]]
# Out:
# 0                                To help with my career
# 1                                    I heard it was fun
# 2                                    I like a challenge
# 3                                    I heard it was fun
# 4                                    I heard it was fun
# 5                                    I heard it was fun
# 6                                To help with my career
# 7                                To help with my career
# 8                           I lost my mind for a minute
# 9                                    I heard it was fun
# 10                               To help with my career
# 11                               To help with my career
# 12                               To help with my career
# 13                                   I heard it was fun
# 14    I code/build websites in my spare time as a hobby
# 15                               To help with my career
# 16                          I lost my mind for a minute
# ...

# %% [markdown]
# This creates a series of all of the responses

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# To finish my major                                    1
# Recommended by a professor.                           1
# I like a challenge                                    1
# I code/build websites in my spare time as a hobby     1
# Wanted to try something completely different          1
# i am living in Santiago de Chile                      1
# Name: Enrollment, dtype: int64

# %% [markdown]
# Finally, this sums it all up

# %% [markdown]
# **3.)**

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %% [markdown]
# a.)

# %%
df538 = pd.read_csv(url)

# %% [markdown]
# b.)

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# c.)

# %%
df538(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-fd6aa3bd23fd> in <module>()
#       1
# ----> 2 df538(2)
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# d.)

# %%
df538.set_index("Major", inplace = True)

# %% [markdown]
# e.)

# %%
df538.sort_values("Total")
# Out:
#                                                     level_0  index  Rank  \
# Major
# MILITARY TECHNOLOGIES                                    73     73    74
# MATHEMATICS AND COMPUTER SCIENCE                         52     52    53
# SOIL SCIENCE                                            112    112   113
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                   33     33    34
# MINING AND MINERAL ENGINEERING                            1      1     2
# EDUCATIONAL ADMINISTRATION AND SUPERVISION              120    120   121
# SCHOOL STUDENT COUNSELING                                55     55    56
# METALLURGICAL ENGINEERING                                 2      2     3
# LIBRARY SCIENCE                                         172    172   173
# COURT REPORTING                                          19     19    20
# NAVAL ARCHITECTURE AND MARINE ENGINEERING                 3      3     4
# BOTANY                                                   83     83    84
# ...

# %% [markdown]
# f.)

# %%
df538.sort_values("Total", ascending =False).head(10)
# Out:
#                                         level_0  index  Rank  Major_code  \
# Major
# PSYCHOLOGY                                  145    145   146        5200
# BUSINESS MANAGEMENT AND ADMINISTRATION       76     76    77        6203
# BIOLOGY                                     123    123   124        3600
# GENERAL BUSINESS                             57     57    58        6200
# COMMUNICATIONS                               93     93    94        1901
# NURSING                                      34     34    35        6107
# MARKETING AND MARKETING RESEARCH             77     77    78        6206
# ACCOUNTING                                   40     40    41        6201
# ENGLISH LANGUAGE AND LITERATURE             137    137   138        3301
# POLITICAL SCIENCE AND GOVERNMENT             78     78    79        5506
#
#                                            Total       Men     Women  \
# Major
# PSYCHOLOGY                              393735.0   86648.0  307087.0
# ...

# %% [markdown]
# G.)

# %%
Top_10 = df538.sort_values("Total", ascending =False).head(10)

# %%
Top_10
# Out:
#                                         level_0  index  Rank  Major_code  \
# Major
# PSYCHOLOGY                                  145    145   146        5200
# BUSINESS MANAGEMENT AND ADMINISTRATION       76     76    77        6203
# BIOLOGY                                     123    123   124        3600
# GENERAL BUSINESS                             57     57    58        6200
# COMMUNICATIONS                               93     93    94        1901
# NURSING                                      34     34    35        6107
# MARKETING AND MARKETING RESEARCH             77     77    78        6206
# ACCOUNTING                                   40     40    41        6201
# ENGLISH LANGUAGE AND LITERATURE             137    137   138        3301
# POLITICAL SCIENCE AND GOVERNMENT             78     78    79        5506
#
#                                            Total       Men     Women  \
# Major
# PSYCHOLOGY                              393735.0   86648.0  307087.0
# ...

# %%
Top_10["Median"].sort_values().plot(kind="barh")

# %%
Top_10["P25th"].sort_values().plot(kind="barh")
